# %%
from pypokerengine.players import BasePokerPlayer

class FishPlayer(BasePokerPlayer):  # Do not forget to make parent class as "BasePokerPlayer"

    #  we define the logic to make an action through this method. (so this method would be the core of your AI)
    def declare_action(self, valid_actions, hole_card, round_state):
        # valid_actions format => [raise_action_info, call_action_info, fold_action_info]
        call_action_info = valid_actions[1]
        action, amount = call_action_info["action"], call_action_info["amount"]
        return action, amount   # action returned here is sent to the poker engine

    def receive_game_start_message(self, game_info):
        pass

    def receive_round_start_message(self, round_count, hole_card, seats):
        pass

    def receive_street_start_message(self, street, round_state):
        pass

    def receive_game_update_message(self, action, round_state):
        pass

    def receive_round_result_message(self, winners, hand_info, round_state):
        pass

# %%
from pypokerengine.api.game import setup_config, start_poker

config = setup_config(max_round=10, initial_stack=100, small_blind_amount=5)
config.register_player(name="p1", algorithm=FishPlayer())
config.register_player(name="p2", algorithm=FishPlayer())
config.register_player(name="p3", algorithm=FishPlayer())
game_result = start_poker(config, verbose=1)
# Out:
# Started the round 1
# Street "preflop" started. (community card = [])
# "p1" declared "call:10"
# "p2" declared "call:10"
# "p3" declared "call:10"
# Street "flop" started. (community card = ['S7', 'D8', 'HT'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# Street "turn" started. (community card = ['S7', 'D8', 'HT', 'D5'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# Street "river" started. (community card = ['S7', 'D8', 'HT', 'D5', 'CJ'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# "['p2']" won the round 1 (stack = {'p1': 90, 'p2': 120, 'p3': 90})
# Started the round 2
# Street "preflop" started. (community card = [])
# "p2" declared "call:10"
# "p3" declared "call:10"
# "p1" declared "call:10"
# Street "flop" started. (community card = ['S6', 'SQ', 'D7'])
# "p3" declared "call:0"
# "p1" declared "call:0"
# "p2" declared "call:0"
# Street "turn" started. (community card = ['S6', 'SQ', 'D7', 'H7'])
# "p3" declared "call:0"
# "p1" declared "call:0"
# "p2" declared "call:0"
# Street "river" started. (community card = ['S6', 'SQ', 'D7', 'H7', 'HA'])
# "p3" declared "call:0"
# "p1" declared "call:0"
# "p2" declared "call:0"
# "['p2']" won the round 2 (stack = {'p1': 80, 'p2': 140, 'p3': 80})
# Started the round 3
# Street "preflop" started. (community card = [])
# "p3" declared "call:10"
# "p1" declared "call:10"
# "p2" declared "call:10"
# Street "flop" started. (community card = ['CQ', 'C3', 'S2'])
# "p1" declared "call:0"
# "p2" declared "call:0"
# "p3" declared "call:0"
# Street "turn" started. (community card = ['CQ', 'C3', 'S2', 'C8'])
# "p1" declared "call:0"
# "p2" declared "call:0"
# "p3" declared "call:0"
# Street "river" started. (community card = ['CQ', 'C3', 'S2', 'C8', 'D5'])
# "p1" declared "call:0"
# "p2" declared "call:0"
# "p3" declared "call:0"
# "['p3']" won the round 3 (stack = {'p1': 70, 'p2': 130, 'p3': 100})
# Started the round 4
# Street "preflop" started. (community card = [])
# "p1" declared "call:10"
# "p2" declared "call:10"
# "p3" declared "call:10"
# Street "flop" started. (community card = ['SQ', 'CA', 'HJ'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# Street "turn" started. (community card = ['SQ', 'CA', 'HJ', 'H8'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# Street "river" started. (community card = ['SQ', 'CA', 'HJ', 'H8', 'C6'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# "['p2']" won the round 4 (stack = {'p1': 60, 'p2': 150, 'p3': 90})
# Started the round 5
# Street "preflop" started. (community card = [])
# "p2" declared "call:10"
# "p3" declared "call:10"
# "p1" declared "call:10"
# Street "flop" started. (community card = ['H9', 'H6', 'C7'])
# "p3" declared "call:0"
# "p1" declared "call:0"
# "p2" declared "call:0"
# Street "turn" started. (community card = ['H9', 'H6', 'C7', 'HT'])
# "p3" declared "call:0"
# "p1" declared "call:0"
# "p2" declared "call:0"
# Street "river" started. (community card = ['H9', 'H6', 'C7', 'HT', 'DJ'])
# "p3" declared "call:0"
# "p1" declared "call:0"
# "p2" declared "call:0"
# "['p2']" won the round 5 (stack = {'p1': 50, 'p2': 170, 'p3': 80})
# Started the round 6
# Street "preflop" started. (community card = [])
# "p3" declared "call:10"
# "p1" declared "call:10"
# "p2" declared "call:10"
# Street "flop" started. (community card = ['S9', 'H8', 'DJ'])
# "p1" declared "call:0"
# "p2" declared "call:0"
# "p3" declared "call:0"
# Street "turn" started. (community card = ['S9', 'H8', 'DJ', 'C7'])
# "p1" declared "call:0"
# "p2" declared "call:0"
# "p3" declared "call:0"
# Street "river" started. (community card = ['S9', 'H8', 'DJ', 'C7', 'HA'])
# "p1" declared "call:0"
# "p2" declared "call:0"
# "p3" declared "call:0"
# "['p1']" won the round 6 (stack = {'p1': 70, 'p2': 160, 'p3': 70})
# Started the round 7
# Street "preflop" started. (community card = [])
# "p1" declared "call:10"
# "p2" declared "call:10"
# "p3" declared "call:10"
# Street "flop" started. (community card = ['ST', 'S4', 'D7'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# Street "turn" started. (community card = ['ST', 'S4', 'D7', 'H9'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# Street "river" started. (community card = ['ST', 'S4', 'D7', 'H9', 'D9'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# "['p2']" won the round 7 (stack = {'p1': 60, 'p2': 180, 'p3': 60})
# Started the round 8
# Street "preflop" started. (community card = [])
# "p2" declared "call:10"
# "p3" declared "call:10"
# "p1" declared "call:10"
# Street "flop" started. (community card = ['H6', 'HQ', 'C4'])
# "p3" declared "call:0"
# "p1" declared "call:0"
# "p2" declared "call:0"
# Street "turn" started. (community card = ['H6', 'HQ', 'C4', 'D7'])
# "p3" declared "call:0"
# "p1" declared "call:0"
# "p2" declared "call:0"
# Street "river" started. (community card = ['H6', 'HQ', 'C4', 'D7', 'H8'])
# "p3" declared "call:0"
# "p1" declared "call:0"
# "p2" declared "call:0"
# "['p3']" won the round 8 (stack = {'p1': 50, 'p2': 170, 'p3': 80})
# Started the round 9
# Street "preflop" started. (community card = [])
# "p3" declared "call:10"
# "p1" declared "call:10"
# "p2" declared "call:10"
# Street "flop" started. (community card = ['S5', 'CT', 'HA'])
# "p1" declared "call:0"
# "p2" declared "call:0"
# "p3" declared "call:0"
# Street "turn" started. (community card = ['S5', 'CT', 'HA', 'H3'])
# "p1" declared "call:0"
# "p2" declared "call:0"
# "p3" declared "call:0"
# Street "river" started. (community card = ['S5', 'CT', 'HA', 'H3', 'HK'])
# "p1" declared "call:0"
# "p2" declared "call:0"
# "p3" declared "call:0"
# "['p2']" won the round 9 (stack = {'p1': 40, 'p2': 190, 'p3': 70})
# Started the round 10
# Street "preflop" started. (community card = [])
# "p1" declared "call:10"
# "p2" declared "call:10"
# "p3" declared "call:10"
# Street "flop" started. (community card = ['ST', 'S6', 'C3'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# Street "turn" started. (community card = ['ST', 'S6', 'C3', 'C5'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# Street "river" started. (community card = ['ST', 'S6', 'C3', 'C5', 'D5'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# "['p3']" won the round 10 (stack = {'p1': 30, 'p2': 180, 'p3': 90})
